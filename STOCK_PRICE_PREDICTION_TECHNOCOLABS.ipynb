# %%
##### File Created by RAHUL CHAWLA #####

# %%
import pandas as pd    #importing necessary libraries
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('DataFrame.csv')      #Reading csv file and creating DataFrame
print(data.shape)
data.head()
# Out:
# (22805, 8)
#     Type      Date   Time      open      high       low     close  Unnamed: 7
# 0  NIFTY  20210101  09:16  13997.90  14020.85  13991.35  14013.15         NaN
# 1  NIFTY  20210101  09:17  14014.85  14018.55  14008.15  14009.05         NaN
# 2  NIFTY  20210101  09:18  14008.05  14013.10  14005.05  14012.70         NaN
# 3  NIFTY  20210101  09:19  14013.65  14019.10  14013.65  14016.20         NaN
# 4  NIFTY  20210101  09:20  14015.45  14017.80  14011.95  14015.45         NaN

# %%
data.drop('Unnamed: 7' , axis = 1 , inplace = True)   #Dropping unnecessary Column:-> Unnamed: 7

# %%
data.rename(columns = str.upper , inplace = True)

# %%
data
# Out:
#         TYPE      DATE   TIME      OPEN      HIGH       LOW     CLOSE
# 0      NIFTY  20210101  09:16  13997.90  14020.85  13991.35  14013.15
# 1      NIFTY  20210101  09:17  14014.85  14018.55  14008.15  14009.05
# 2      NIFTY  20210101  09:18  14008.05  14013.10  14005.05  14012.70
# 3      NIFTY  20210101  09:19  14013.65  14019.10  14013.65  14016.20
# 4      NIFTY  20210101  09:20  14015.45  14017.80  14011.95  14015.45
# ...      ...       ...    ...       ...       ...       ...       ...
# 22800  NIFTY  20210331  15:27  14687.35  14694.35  14686.30  14690.60
# 22801  NIFTY  20210331  15:28  14690.90  14690.90  14686.05  14689.30
# 22802  NIFTY  20210331  15:29  14690.30  14694.10  14688.55  14691.30
# 22803  NIFTY  20210331  15:30  14689.85  14693.55  14689.45  14693.05
# 22804  NIFTY  20210331  15:31  14690.70  14690.70  14690.70  14690.70
#
# [22805 rows x 7 columns]

# %% [markdown]
# # CONVERTING STRING INTO DATE TIME SERIES

# %%
import datetime
data['DATE'] = pd.to_datetime(data['DATE'] , format = "%Y%m%d")

# %%
data.head()
# Out:
#     TYPE       DATE   TIME      OPEN      HIGH       LOW     CLOSE
# 0  NIFTY 2021-01-01  09:16  13997.90  14020.85  13991.35  14013.15
# 1  NIFTY 2021-01-01  09:17  14014.85  14018.55  14008.15  14009.05
# 2  NIFTY 2021-01-01  09:18  14008.05  14013.10  14005.05  14012.70
# 3  NIFTY 2021-01-01  09:19  14013.65  14019.10  14013.65  14016.20
# 4  NIFTY 2021-01-01  09:20  14015.45  14017.80  14011.95  14015.45

# %%
import missingno as msno       #Checking for the missing entries
msno.bar(data)
# Out:
# <AxesSubplot:>

# %%
data.describe()   #Statistics of the Dataset
# Out:
#                OPEN          HIGH           LOW         CLOSE
# count  22805.000000  22805.000000  22805.000000  22805.000000
# mean   14703.322396  14707.486481  14699.102201  14703.260816
# std      391.377498    391.265231    391.551643    391.366248
# min    13604.750000  13614.400000  13596.750000  13602.800000
# 25%    14462.250000  14465.950000  14458.050000  14461.950000
# 50%    14739.500000  14743.000000  14735.850000  14739.450000
# 75%    15037.000000  15041.250000  15032.500000  15036.850000
# max    15429.500000  15431.750000  15427.900000  15430.200000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22805 entries, 0 to 22804
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TYPE    22805 non-null  object
#  1   DATE    22805 non-null  datetime64[ns]
#  2   TIME    22805 non-null  object
#  3   OPEN    22805 non-null  float64
#  4   HIGH    22805 non-null  float64
#  5   LOW     22805 non-null  float64
#  6   CLOSE   22805 non-null  float64
# dtypes: datetime64[ns](1), float64(4), object(2)
# memory usage: 1.2+ MB

# %%
data[data.duplicated()]       #Checking for the duplicated entries
# Out:
# Empty DataFrame
# Columns: [TYPE, DATE, TIME, OPEN, HIGH, LOW, CLOSE]
# Index: []

# %% [markdown]
# # CONSIDERING ANOTHER DATASET

# %%
df2 = pd.read_csv('MSFT.csv')
df2.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close      Volume
# 0  1986-03-13  0.088542  0.101563  0.088542  0.097222   0.061751  1031788800
# 1  1986-03-14  0.097222  0.102431  0.097222  0.100694   0.063956   308160000
# 2  1986-03-17  0.100694  0.103299  0.100694  0.102431   0.065059   133171200
# 3  1986-03-18  0.102431  0.103299  0.098958  0.099826   0.063405    67766400
# 4  1986-03-19  0.099826  0.100694  0.097222  0.098090   0.062302    47894400

# %%
df2.rename(columns = str.upper , inplace = True)

# %%
df2['DATE'] = pd.to_datetime(df2['DATE'] , format = "%Y-%m-%d")

# %%
df2.head()
# Out:
#         DATE      OPEN      HIGH       LOW     CLOSE  ADJ CLOSE      VOLUME
# 0 1986-03-13  0.088542  0.101563  0.088542  0.097222   0.061751  1031788800
# 1 1986-03-14  0.097222  0.102431  0.097222  0.100694   0.063956   308160000
# 2 1986-03-17  0.100694  0.103299  0.100694  0.102431   0.065059   133171200
# 3 1986-03-18  0.102431  0.103299  0.098958  0.099826   0.063405    67766400
# 4 1986-03-19  0.099826  0.100694  0.097222  0.098090   0.062302    47894400

# %%
df2[df2.duplicated()]
# Out:
# Empty DataFrame
# Columns: [DATE, OPEN, HIGH, LOW, CLOSE, ADJ CLOSE, VOLUME]
# Index: []

# %%
df2.describe()
# Out:
#               OPEN         HIGH          LOW        CLOSE    ADJ CLOSE  \
# count  8857.000000  8857.000000  8857.000000  8857.000000  8857.000000
# mean     34.831233    35.209355    34.449657    34.840895    29.886536
# std      44.060163    44.513443    43.597704    44.080986    44.195101
# min       0.088542     0.092014     0.088542     0.090278     0.057340
# 25%       3.843750     3.875000     3.812500     3.851563     2.446323
# 50%      26.590000    26.879999    26.290001    26.590000    18.686628
# 75%      36.730000    37.000000    36.110001    36.660000    27.218300
# max     261.660004   263.190002   260.170013   261.970001   261.970001
#
#              VOLUME
# count  8.857000e+03
# mean   5.953411e+07
# std    3.858121e+07
# min    2.304000e+06
# 25%    3.559720e+07
# 50%    5.269680e+07
# 75%    7.339520e+07
# max    1.031789e+09

# %%
df2.isna().sum()
# Out:
# DATE         0
# OPEN         0
# HIGH         0
# LOW          0
# CLOSE        0
# ADJ CLOSE    0
# VOLUME       0
# dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8857 entries, 0 to 8856
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   DATE       8857 non-null   datetime64[ns]
#  1   OPEN       8857 non-null   float64
#  2   HIGH       8857 non-null   float64
#  3   LOW        8857 non-null   float64
#  4   CLOSE      8857 non-null   float64
#  5   ADJ CLOSE  8857 non-null   float64
#  6   VOLUME     8857 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 484.5 KB

# %% [markdown]
# # EDA ANALYSIS (DataFrame.csv)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
d1 = data.copy()
d1
# Out:
#         TYPE       DATE   TIME      OPEN      HIGH       LOW     CLOSE
# 0      NIFTY 2021-01-01  09:16  13997.90  14020.85  13991.35  14013.15
# 1      NIFTY 2021-01-01  09:17  14014.85  14018.55  14008.15  14009.05
# 2      NIFTY 2021-01-01  09:18  14008.05  14013.10  14005.05  14012.70
# 3      NIFTY 2021-01-01  09:19  14013.65  14019.10  14013.65  14016.20
# 4      NIFTY 2021-01-01  09:20  14015.45  14017.80  14011.95  14015.45
# ...      ...        ...    ...       ...       ...       ...       ...
# 22800  NIFTY 2021-03-31  15:27  14687.35  14694.35  14686.30  14690.60
# 22801  NIFTY 2021-03-31  15:28  14690.90  14690.90  14686.05  14689.30
# 22802  NIFTY 2021-03-31  15:29  14690.30  14694.10  14688.55  14691.30
# 22803  NIFTY 2021-03-31  15:30  14689.85  14693.55  14689.45  14693.05
# 22804  NIFTY 2021-03-31  15:31  14690.70  14690.70  14690.70  14690.70
#
# [22805 rows x 7 columns]

# %%
d1.columns
d1 = d1.set_index(['TYPE','DATE','TIME'])

# %%
feature = ['OPEN', 'HIGH', 'LOW', 'CLOSE']

# %%
list(enumerate(feature))
# Out:
# [(0, 'OPEN'), (1, 'HIGH'), (2, 'LOW'), (3, 'CLOSE')]

# %%
plt.figure(figsize=(15,12))
for i in enumerate(feature):
    plt.subplot(2,2,i[0]+1)
    base_color = sns.color_palette()[i[0]]
    sns.distplot(d1[i[1]] , kde = False , color = base_color)
    plt.xlabel(i[1]);

# %%
color = sns.PairGrid(d1)
color.map_upper(sns.scatterplot,color = 'green')
color.map_lower(sns.scatterplot,color = 'orange')
color.map_diag(plt.hist)

# %%
plt.figure(figsize=(15,10))         #creating Box plots of various attributes
for i in enumerate(feature):
    plt.subplot(2,2,i[0]+1)
    base_color = sns.color_palette()[i[0]]
    sns.boxplot(x = d1[i[1]] , color = base_color)
    plt.xlabel(i[1]);

# %%
sns.heatmap(d1.corr() , vmin = -1 , vmax = 1 , annot = True , cmap = 'Blues')     #heat map to determine correlation
# Out:
# <AxesSubplot:>

# %% [markdown]
# # EDA ANALYSIS (MSFT.csv)

# %%
d2 = df2.copy()
d2
# Out:
#            DATE        OPEN        HIGH         LOW       CLOSE   ADJ CLOSE  \
# 0    1986-03-13    0.088542    0.101563    0.088542    0.097222    0.061751
# 1    1986-03-14    0.097222    0.102431    0.097222    0.100694    0.063956
# 2    1986-03-17    0.100694    0.103299    0.100694    0.102431    0.065059
# 3    1986-03-18    0.102431    0.103299    0.098958    0.099826    0.063405
# 4    1986-03-19    0.099826    0.100694    0.097222    0.098090    0.062302
# ...         ...         ...         ...         ...         ...         ...
# 8852 2021-04-27  261.579987  263.190002  260.119995  261.970001  261.970001
# 8853 2021-04-28  256.079987  256.540009  252.949997  254.559998  254.559998
# 8854 2021-04-29  255.460007  256.100006  249.000000  252.509995  252.509995
# 8855 2021-04-30  249.740005  253.080002  249.600006  252.179993  252.179993
# 8856 2021-05-03  253.399994  254.350006  251.119995  251.860001  251.860001
#
#           VOLUME
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 8852    31014200
# 8853    46903100
# 8854    40589000
# 8855    30929200
# 8856    19598900
#
# [8857 rows x 7 columns]

# %%
d2 = d2.set_index('DATE')

# %%
feat = d2.columns

# %%
list(enumerate(feat))
# Out:
# [(0, 'OPEN'),
#  (1, 'HIGH'),
#  (2, 'LOW'),
#  (3, 'CLOSE'),
#  (4, 'ADJ CLOSE'),
#  (5, 'VOLUME')]

# %%
plt.figure(figsize=(15,15))         #creating distribution plots of various attributes
for i in enumerate(feat):
    plt.subplot(3,2,i[0]+1)
    base_color = sns.color_palette()[i[0]]
    sns.distplot(d2[i[1]] , color = base_color)
    plt.xlabel(i[1]);
    plt.title(f'Distribution plot of {i[1]}')

# %%
sns.pairplot(data = d2)      #Plots b/w various attributes

# %%
plt.figure(figsize=(15,10))         #creating Box plots of various attributes
for i in enumerate(feat):
    plt.subplot(3,2,i[0]+1)
    base_color = sns.color_palette()[i[0]]
    sns.boxplot(x = d2[i[1]] , color = base_color)
    plt.xlabel(i[1]);

# %%
plt.figure(figsize=(15,10))         #creating Violin plots of various attributes
for i in enumerate(feat):
    plt.subplot(3,2,i[0]+1)
    base_color = sns.color_palette()[i[0]]
    sns.violinplot(x = d2[i[1]] , color = base_color)
    plt.xlabel(i[1]);

# %%
sns.heatmap(d2.corr() , vmin = -1 , vmax = 1 , annot = True , cmap = 'Paired_r')     #heat map to determine correlation
# Out:
# <AxesSubplot:>

# %% [markdown]
# # AS SEEN THE PRESENCE OF OUTLIERS IN MSFT, SO SUPRESSING THEIR EFFECT

# %%
iqr1 = d2['OPEN'].quantile(0.75) - d2['OPEN'].quantile(0.25) 
iqr1
# Out:
# 32.88624954223633

# %%
upper_whisker = d2['OPEN'].quantile(0.75)+(iqr1*1.5)
lower_whisker = d2['OPEN'].quantile(0.25)-(iqr1*1.5)
print(upper_whisker)
print(lower_whisker)
# Out:
# 86.05937385559082
# -45.48562431335449

# %%
iqr2 = d2['CLOSE'].quantile(0.75) - d2['CLOSE'].quantile(0.25) 
iqr2
# Out:
# 32.80843687057495

# %%
upper_whisker = d2['CLOSE'].quantile(0.75)+(iqr2*1.5)
lower_whisker = d2['CLOSE'].quantile(0.25)-(iqr2*1.5)
print(upper_whisker)
print(lower_whisker)
# Out:
# 85.87265515327454
# -45.36109232902527

# %%
iqr3 = d2['HIGH'].quantile(0.75) - d2['HIGH'].quantile(0.25) 
iqr3
# Out:
# 33.125

# %%
upper_whisker = d2['HIGH'].quantile(0.75)+(iqr3*1.5)
lower_whisker = d2['HIGH'].quantile(0.25)-(iqr3*1.5)
print(upper_whisker)
print(lower_whisker)
# Out:
# 86.6875
# -45.8125

# %%
iqr4 = d2['LOW'].quantile(0.75) - d2['LOW'].quantile(0.25) 
iqr4
# Out:
# 32.29750061035156

# %%
upper_whisker = d2['LOW'].quantile(0.75)+(iqr4*1.5)
lower_whisker = d2['LOW'].quantile(0.25)-(iqr4*1.5)
print(upper_whisker)
print(lower_whisker)
# Out:
# 84.5562515258789
# -44.633750915527344

# %%
iqr5 = d2['ADJ CLOSE'].quantile(0.75) - d2['ADJ CLOSE'].quantile(0.25) 
iqr5
# Out:
# 24.771977186203003

# %%
upper_whisker = d2['ADJ CLOSE'].quantile(0.75)+(iqr5*1.5)
lower_whisker = d2['ADJ CLOSE'].quantile(0.25)-(iqr5*1.5)
print(upper_whisker)
print(lower_whisker)
# Out:
# 64.37626564502716
# -34.71164309978485

# %%
iqr6 = d2['VOLUME'].quantile(0.75) - d2['VOLUME'].quantile(0.25) 
iqr6
# Out:
# 37798000.0

# %%
upper_whisker = d2['VOLUME'].quantile(0.75)+(iqr6*1.5)
lower_whisker = d2['VOLUME'].quantile(0.25)-(iqr6*1.5)
print(upper_whisker)
print(lower_whisker)
# Out:
# 130092200.0
# -21099800.0

# %%
d2.loc[d2['OPEN'] >= 86.05937385559082 , 'OPEN'] = 86.05937385559082
d2.loc[d2['CLOSE'] >= 85.87265515327454 , 'CLOSE'] = 85.87265515327454
d2.loc[d2['HIGH'] >= 86.6875 , 'HIGH'] = 86.6875
d2.loc[d2['LOW'] >= 84.5562515258789 , 'LOW'] = 84.5562515258789
d2.loc[d2['ADJ CLOSE'] >= 64.37626564502716 , 'ADJ CLOSE'] = 64.37626564502716
d2.loc[d2['VOLUME'] >= 130092200.0 , 'VOLUME'] = 130092200.0

# %%
d_remo_outlier = d2
d_remo_outlier
# Out:
#                  OPEN       HIGH        LOW      CLOSE  ADJ CLOSE     VOLUME
# DATE
# 1986-03-13   0.088542   0.101563   0.088542   0.097222   0.061751  130092200
# 1986-03-14   0.097222   0.102431   0.097222   0.100694   0.063956  130092200
# 1986-03-17   0.100694   0.103299   0.100694   0.102431   0.065059  130092200
# 1986-03-18   0.102431   0.103299   0.098958   0.099826   0.063405   67766400
# 1986-03-19   0.099826   0.100694   0.097222   0.098090   0.062302   47894400
# ...               ...        ...        ...        ...        ...        ...
# 2021-04-27  86.059374  86.687500  84.556252  85.872655  64.376266   31014200
# 2021-04-28  86.059374  86.687500  84.556252  85.872655  64.376266   46903100
# 2021-04-29  86.059374  86.687500  84.556252  85.872655  64.376266   40589000
# 2021-04-30  86.059374  86.687500  84.556252  85.872655  64.376266   30929200
# 2021-05-03  86.059374  86.687500  84.556252  85.872655  64.376266   19598900
#
# [8857 rows x 6 columns]

# %%
l = ['OPEN' , 'HIGH' , 'LOW' , 'CLOSE' , 'ADJ CLOSE' , 'VOLUME']
list(enumerate(l))
# Out:
# [(0, 'OPEN'),
#  (1, 'HIGH'),
#  (2, 'LOW'),
#  (3, 'CLOSE'),
#  (4, 'ADJ CLOSE'),
#  (5, 'VOLUME')]

# %%
plt.figure(figsize=(15,12))#creating Box plots of various columns after removing outliers
for i in enumerate(l):
    plt.subplot(3,2,i[0]+1)
    base_color = sns.color_palette()[i[0]]
    sns.boxplot(x = d2[i[1]] , color = base_color)
    plt.xlabel(i[1]);

# %% [markdown]
# # MODELLING PART FOR DATAFRAME.CSV DATASET

# %% [markdown]
# # SEPERATING THE DATE COLUMN AND TIME COLUMN

# %%
d_1 = data.copy()

# %%
d_1.drop(['TYPE'],axis=1,inplace=True)

# %%
d_1['DAY']=pd.to_datetime(d_1['DATE'], format="%Y/%m/%d").dt.day

# %%
d_1['month']=pd.to_datetime(d_1['DATE'], format='%Y/%m/%d').dt.month

# %%
d_1['YEAR']=pd.to_datetime(d_1['DATE'], format='%Y/%m/%d').dt.year

# %%
d_1.drop(['DATE'],axis=1,inplace=True)

# %%
d_1['Time_hour']=pd.to_datetime(d_1['TIME']).dt.hour

# %%
d_1['time_minute']=pd.to_datetime(d_1['TIME']).dt.minute

# %%
d_1.drop(['TIME'],axis=1,inplace=True)

# %%
d_1.head()
# Out:
#        OPEN      HIGH       LOW     CLOSE  DAY  month  YEAR  Time_hour  \
# 0  13997.90  14020.85  13991.35  14013.15    1      1  2021          9
# 1  14014.85  14018.55  14008.15  14009.05    1      1  2021          9
# 2  14008.05  14013.10  14005.05  14012.70    1      1  2021          9
# 3  14013.65  14019.10  14013.65  14016.20    1      1  2021          9
# 4  14015.45  14017.80  14011.95  14015.45    1      1  2021          9
#
#    time_minute
# 0           16
# 1           17
# 2           18
# 3           19
# 4           20

# %%
X = d_1.loc[:,d_1.columns!='CLOSE']
X
# Out:
#            OPEN      HIGH       LOW  DAY  month  YEAR  Time_hour  time_minute
# 0      13997.90  14020.85  13991.35    1      1  2021          9           16
# 1      14014.85  14018.55  14008.15    1      1  2021          9           17
# 2      14008.05  14013.10  14005.05    1      1  2021          9           18
# 3      14013.65  14019.10  14013.65    1      1  2021          9           19
# 4      14015.45  14017.80  14011.95    1      1  2021          9           20
# ...         ...       ...       ...  ...    ...   ...        ...          ...
# 22800  14687.35  14694.35  14686.30   31      3  2021         15           27
# 22801  14690.90  14690.90  14686.05   31      3  2021         15           28
# 22802  14690.30  14694.10  14688.55   31      3  2021         15           29
# 22803  14689.85  14693.55  14689.45   31      3  2021         15           30
# 22804  14690.70  14690.70  14690.70   31      3  2021         15           31
#
# [22805 rows x 8 columns]

# %%
y=d_1['CLOSE']
y
# Out:
# 0        14013.15
# 1        14009.05
# 2        14012.70
# 3        14016.20
# 4        14015.45
#            ...
# 22800    14690.60
# 22801    14689.30
# 22802    14691.30
# 22803    14693.05
# 22804    14690.70
# Name: CLOSE, Length: 22805, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (18244, 8) (4561, 8) (18244,) (4561,)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc= StandardScaler()

# %%
X_train_std=sc.fit_transform(X_train)

# %%
X_test_std=sc.transform(X_test)

# %%
X_train_std
# Out:
# array([[ 1.05314965,  1.04448231,  1.04056985, ...,  0.        ,
#          0.57862783,  1.57763269],
#        [ 1.11093268,  1.12650169,  1.11958297, ...,  0.        ,
#         -1.03034734, -1.47114428],
#        [-2.22510865, -2.15991211, -2.28835392, ...,  0.        ,
#         -1.5666724 , -0.76758037],
#        ...,
#        [ 1.20151495,  1.22261814,  1.21178628, ...,  0.        ,
#         -1.5666724 ,  0.52228681],
#        [ 1.07569912,  1.06575609,  1.06528546, ...,  0.        ,
#          0.04230277,  1.57763269],
#        [-0.57515319, -0.57860421, -0.56504839, ...,  0.        ,
#         -1.03034734,  0.87406877]])

# %% [markdown]
# # SVM BASED APPROACH (LINEAR MODEL)

# %%
from sklearn.svm import SVR
svr = SVR(kernel='linear', C = 22)

# %%
svr.fit(X_train_std,y_train)
# Out:
# SVR(C=22, kernel='linear')

# %%
y_train_pred = svr.predict(X_train_std)

# %%
y_test_pred = svr.predict(X_test_std)

# %%
result = pd.DataFrame({'Actual' : y_test , 'Predicted' : y_test_pred}).reset_index()[['Actual' , 'Predicted']]
result
# Out:
#         Actual     Predicted
# 0     14866.05  14864.330852
# 1     15233.20  15236.369133
# 2     14438.70  14440.477947
# 3     14748.45  14749.253550
# 4     14188.90  14190.832200
# ...        ...           ...
# 4556  14781.75  14785.069750
# 4557  13839.05  13828.236374
# 4558  15146.60  15147.668246
# 4559  14045.60  14044.166270
# 4560  14273.15  14271.406432
#
# [4561 rows x 2 columns]

# %%
plt.figure(figsize=(20,15))
plt.plot(result['Actual'],label = 'Actual' , color = 'black')
plt.plot(result['Predicted'],label = 'Predicted' , color = 'pink')
plt.title('Plot of Actual v/s Predicted results')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
mse = mean_squared_error(y_test,y_test_pred)
print("Mean_squared_error is: ", mse)
# Out:
# Mean_squared_error is:  7.227718511534193

# %%
r2score = r2_score(y_test , y_test_pred)
print("R2 score is: " , r2score)
# Out:
# R2 score is:  0.9999538310740537

# %% [markdown]
# # MODELLING PART FOR MSFT.CSV DATASET WITH OUTLIERS

# %% [markdown]
# # SEPERATING THE DATE COLUMN

# %%
d_2 = df2.copy()
d_2.dtypes
# Out:
# DATE         datetime64[ns]
# OPEN                float64
# HIGH                float64
# LOW                 float64
# CLOSE               float64
# ADJ CLOSE           float64
# VOLUME                int64
# dtype: object

# %%
d_2['YEAR'] = pd.to_datetime(d_2['DATE'] , format = '%Y-%m-%d').dt.year
d_2['MONTH'] = pd.to_datetime(d_2['DATE'] , format = '%Y-%m-%d').dt.month
d_2['DAY'] = pd.to_datetime(d_2['DATE'] , format = '%Y-%m-%d').dt.day

# %%
d_2.drop('DATE' , axis =1 , inplace = True)

# %%
d_2.dtypes
# Out:
# OPEN         float64
# HIGH         float64
# LOW          float64
# CLOSE        float64
# ADJ CLOSE    float64
# VOLUME         int64
# YEAR           int64
# MONTH          int64
# DAY            int64
# dtype: object

# %%
x = d_2.loc[: , d_2.columns!= 'CLOSE']
x
# Out:
#             OPEN        HIGH         LOW   ADJ CLOSE      VOLUME  YEAR  MONTH  \
# 0       0.088542    0.101563    0.088542    0.061751  1031788800  1986      3
# 1       0.097222    0.102431    0.097222    0.063956   308160000  1986      3
# 2       0.100694    0.103299    0.100694    0.065059   133171200  1986      3
# 3       0.102431    0.103299    0.098958    0.063405    67766400  1986      3
# 4       0.099826    0.100694    0.097222    0.062302    47894400  1986      3
# ...          ...         ...         ...         ...         ...   ...    ...
# 8852  261.579987  263.190002  260.119995  261.970001    31014200  2021      4
# 8853  256.079987  256.540009  252.949997  254.559998    46903100  2021      4
# 8854  255.460007  256.100006  249.000000  252.509995    40589000  2021      4
# 8855  249.740005  253.080002  249.600006  252.179993    30929200  2021      4
# 8856  253.399994  254.350006  251.119995  251.860001    19598900  2021      5
#
#       DAY
# 0      13
# 1      14
# 2      17
# 3      18
# 4      19
# ...   ...
# 8852   27
# 8853   28
# 8854   29
# 8855   30
# 8856    3
#
# [8857 rows x 8 columns]

# %%
y = d_2['CLOSE']
y
# Out:
# 0         0.097222
# 1         0.100694
# 2         0.102431
# 3         0.099826
# 4         0.098090
#            ...
# 8852    261.970001
# 8853    254.559998
# 8854    252.509995
# 8855    252.179993
# 8856    251.860001
# Name: CLOSE, Length: 8857, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
x_train
# Out:
# array([[-0.10197221, -0.10840858, -0.10376951, ..., -0.12267646,
#         -1.02544085,  0.70880399],
#        [ 0.24038047,  0.23429234,  0.17641548, ..., -0.31974318,
#         -0.73464481, -1.3443867 ],
#        [-0.22056844, -0.21923667, -0.21621761, ...,  0.76412375,
#          0.42853938, -0.08965905],
#        ...,
#        [-0.21697802, -0.22301238, -0.21712442, ...,  0.17292361,
#         -0.15305271, -0.08965905],
#        [ 0.10994705,  0.12532433,  0.11265334, ..., -0.41827654,
#         -1.3162369 , -0.6599898 ],
#        [-0.55133637, -0.55346999, -0.5525983 , ..., -0.71387661,
#          1.59172357,  1.73539934]])

# %% [markdown]
# # SVM BASED APPROACH (LINEAR MODEL ON MSFT.CSV)

# %%
from sklearn.svm import SVR
model = SVR(kernel = 'linear' , C = 22)

# %%
model.fit(x_train , y_train)
# Out:
# SVR(C=22, kernel='linear')

# %%
y_train_pred = model.predict(x_train)

# %%
y_test_pred = model.predict(x_test)

# %%
result_1 = pd.DataFrame({'Actual' : y_test , 'Predicted' : y_test_pred}).reset_index()[['Actual' , 'Predicted']]
result_1
# Out:
#          Actual  Predicted
# 0      2.656250   2.717358
# 1     23.480000  23.736530
# 2      0.341146   0.413392
# 3     24.920000  24.885340
# 4     29.370001  29.309059
# ...         ...        ...
# 1767   5.640625   5.708998
# 1768  55.200001  55.439218
# 1769   3.867188   3.900925
# 1770  24.150000  24.195421
# 1771  26.100000  26.395100
#
# [1772 rows x 2 columns]

# %%
plt.figure(figsize=(20,15))
plt.plot(result_1['Actual'],label = 'Actual' , color = 'black')
plt.plot(result_1['Predicted'],label = 'Predicted' , color = 'orange')
plt.title('Plot of Actual v/s Predicted results')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
mse = mean_squared_error(y_test,y_test_pred)
print("Mean_squared_error is: ", mse)
# Out:
# Mean_squared_error is:  0.12769291067653854

# %%
r2score = r2_score(y_test , y_test_pred)
print("R2 score is: " , r2score)
# Out:
# R2 score is:  0.999927440467117

# %% [markdown]
# # MODELLING PART FOR MSFT.CSV DATASET WITH REMOVED OUTLIERS

# %%
d_3 = d_remo_outlier.reset_index()

# %%
d_3.dtypes
# Out:
# DATE         datetime64[ns]
# OPEN                float64
# HIGH                float64
# LOW                 float64
# CLOSE               float64
# ADJ CLOSE           float64
# VOLUME                int64
# dtype: object

# %%
d_3['YEAR'] = pd.to_datetime(d_3['DATE'] , format = '%Y-%m-%d').dt.year
d_3['MONTH'] = pd.to_datetime(d_3['DATE'] , format = '%Y-%m-%d').dt.month
d_3['DAY'] = pd.to_datetime(d_3['DATE'] , format = '%Y-%m-%d').dt.day

# %%
d_3.drop('DATE' , axis =1 , inplace = True)

# %%
d_3.dtypes
# Out:
# OPEN         float64
# HIGH         float64
# LOW          float64
# CLOSE        float64
# ADJ CLOSE    float64
# VOLUME         int64
# YEAR           int64
# MONTH          int64
# DAY            int64
# dtype: object

# %%
x = d_3.loc[: , d_3.columns!= 'CLOSE']
x
# Out:
#            OPEN       HIGH        LOW  ADJ CLOSE     VOLUME  YEAR  MONTH  DAY
# 0      0.088542   0.101563   0.088542   0.061751  130092200  1986      3   13
# 1      0.097222   0.102431   0.097222   0.063956  130092200  1986      3   14
# 2      0.100694   0.103299   0.100694   0.065059  130092200  1986      3   17
# 3      0.102431   0.103299   0.098958   0.063405   67766400  1986      3   18
# 4      0.099826   0.100694   0.097222   0.062302   47894400  1986      3   19
# ...         ...        ...        ...        ...        ...   ...    ...  ...
# 8852  86.059374  86.687500  84.556252  64.376266   31014200  2021      4   27
# 8853  86.059374  86.687500  84.556252  64.376266   46903100  2021      4   28
# 8854  86.059374  86.687500  84.556252  64.376266   40589000  2021      4   29
# 8855  86.059374  86.687500  84.556252  64.376266   30929200  2021      4   30
# 8856  86.059374  86.687500  84.556252  64.376266   19598900  2021      5    3
#
# [8857 rows x 8 columns]

# %%
y = d_3['CLOSE']
y
# Out:
# 0        0.097222
# 1        0.100694
# 2        0.102431
# 3        0.099826
# 4        0.098090
#           ...
# 8852    85.872655
# 8853    85.872655
# 8854    85.872655
# 8855    85.872655
# 8856    85.872655
# Name: CLOSE, Length: 8857, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
x_train
# Out:
# array([[ 0.07085383,  0.06079064,  0.07022257, ..., -0.12267646,
#         -1.02544085,  0.70880399],
#        [ 0.6712359 ,  0.66355956,  0.56401196, ..., -0.31974318,
#         -0.73464481, -1.3443867 ],
#        [-0.13712776, -0.13414239, -0.12795249, ...,  0.76412375,
#          0.42853938, -0.08965905],
#        ...,
#        [-0.13083125, -0.1407834 , -0.12955063, ...,  0.17292361,
#         -0.15305271, -0.08965905],
#        [ 0.4424955 ,  0.47189819,  0.45163954, ..., -0.41827654,
#         -1.3162369 , -0.6599898 ],
#        [-0.71719372, -0.72201787, -0.72077945, ..., -0.71387661,
#          1.59172357,  1.73539934]])

# %% [markdown]
# # SVM BASED APPROACH ON MSFT DATASET ON REMOVAL OF OUTLIERS (LINEAR MODEL)

# %%
from sklearn.svm import SVR
model = SVR(kernel = 'linear' , C = 10)

# %%
model.fit(x_train , y_train)
# Out:
# SVR(C=10, kernel='linear')

# %%
y_train_pred = model.predict(x_train)

# %%
y_test_pred = model.predict(x_test)

# %%
result_2 = pd.DataFrame({'Actual' : y_test , 'Predicted' : y_test_pred}).reset_index()[['Actual' , 'Predicted']]
result_2
# Out:
#          Actual  Predicted
# 0      2.656250   2.577056
# 1     23.480000  23.823610
# 2      0.341146   0.262667
# 3     24.920000  25.063972
# 4     29.370001  29.306055
# ...         ...        ...
# 1767   5.640625   5.597508
# 1768  55.200001  55.545392
# 1769   3.867188   3.765180
# 1770  24.150000  24.256377
# 1771  26.100000  26.388824
#
# [1772 rows x 2 columns]

# %%
plt.figure(figsize=(20,15))
plt.plot(result_2['Actual'],label = 'Actual' , color = 'black')
plt.plot(result_2['Predicted'],label = 'Predicted' , color = 'gold')
plt.title('Plot of Actual v/s Predicted results')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
mse = mean_squared_error(y_test,y_test_pred)
print("Mean_squared_error is: ", mse)
# Out:
# Mean_squared_error is:  0.039352197958188694

# %%
r2score = r2_score(y_test , y_test_pred)
print("R2 score is: " , r2score)
# Out:
# R2 score is:  0.9999371914224405
